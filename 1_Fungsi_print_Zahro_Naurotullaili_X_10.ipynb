# %% [markdown]
# <a href="https://colab.research.google.com/github/zahrolaili05/KKA-X-Semester-1/blob/main/1_Fungsi_print_Zahro_Naurotullaili_X_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Zahro Naurotullaili
#
# Kelas: X-10
#
# No.absen: 34

# %% [markdown]
# #konsep variabel

# %%
print ("zahrolaili05@gmail.com")
print ("zahrolaili05@gmail.com")
print ("zahrolaili05@gmail.com")
# Out:
# zahrolaili05@gmail.com
# zahrolaili05@gmail.com
# zahrolaili05@gmail.com

# %%
email_user_1 ="zahrolaili05@gmail.com"

print (email_user_1)
print (email_user_1)
print (email_user_1)
# Out:
# zahrolaili05@gmail.com
# zahrolaili05@gmail.com
# zahrolaili05@gmail.com

# %% [markdown]
# #Cara penulisan Operator pada Python

# %%
# Tanpa Variabel
print(9+8)
# Out:
# 17

# %%
# Operand disimpan ke variabel
total_iphone= 8+3
print(total_iphone)
# Out:
# 11

# %%
# Operand disimpan ke variabel
iphone_rafa=8
iphone_bela=3

print(iphone_rafa+iphone_bela)
# Out:
# 11

# %%
# Operand dan hasil operasi disimpan ke variabel
iphone_rafa=8
iphone_bela=3

total_iphone=iphone_rafa+iphone_bela
print(total_iphone)
# Out:
# 11

# %%
# Tanpa Variabel
print(24 * 3)
# Out:
# 72

# %%
# Hasil operasi disimpan ke variabel
total_jumlah_botol = 24 * 3
print(total_jumlah_botol)
# Out:
# 72

# %%
# Operand disimpan ke variabel
banyak_botol_per_kardus = 24
jumlah_kardus = 3
print(banyak_botol_per_kardus * jumlah_kardus)
# Out:
# 72

# %%
# Operand hasil operasi disimpan ke variabel
banyak_botol_per_kardus = 24
jumlah_kardus = 3

total_jumlah_botol = banyak_botol_per_kardus * jumlah_kardus

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe-tipe Variabel pada Python

# %%
x = "irkham gantenk"
print(x)
type(x)
# Out:
# irkham gantenk
# str

# %%
q = 0.5
print(q)
type(q)
# Out:
# 0.5
# float

# %%
p = 0
print(p)
type(p)
# Out:
# 0
# int

# %%
r = False
print(r)
type(r)
# Out:
# False
# bool

# %%
s = False
print(r)
type(r)
# Out:
# False
# bool

# %%
t = -6
print(t)
type(t)
# Out:
# -6
# int

# %%
u = -6.5
print(u)
type(u)
# Out:
# -6.5
# float

# %%
u = "-6.5"
print(u)
type(u)
# Out:
# -6.5
# str

# %% [markdown]
# #Pengubahan Type Data

# %%
a = 5
print(a)
type(a)
# Out:
# 5
# int

# %%
a = float (a)
print(a)
type(a)
# Out:
# 5.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 5.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %% [markdown]
# #Jenis-Jenis Operator

# %% [markdown]
# #Operator Aritmatika

# %%
#penjumlahan
a=5
b=2
c=a+b
print (c)
# Out:
# 7

# %%
#pengurangan
d= c-a
print (d)
# Out:
# 2

# %%
#perkalian
e=a*b
print (e)
# Out:
# 10

# %%
#perpangkatan
f=a**b
print(f)
# Out:
# 25

# %%
#pembagian
g=a/b
print(g)
# Out:
# 2.5

# %%
#pembagian bulat
h=a//b
print (h)
# Out:
# 2

# %%
#sisa bagi
j=a%b
print(j)
# Out:
# 1

# %% [markdown]
# #Latihan Soal

# %%
apel_dina=8
ibu_memberi_lagi=5
total= apel_dina+ibu_memberi_lagi
print (total)
# Out:
# 13

# %%
petani_memetik_mangga=30
sisa_mangga=12
total= petani_memetik_mangga-sisa_mangga
print (total)
# Out:
# 18

# %%
meja_asal=6
ditempati=4
total= meja_asal*ditempati
print (total)
# Out:
# 24

# %%
beli_roti=30
dibagikan=4
total=beli_roti/dibagikan
print(total)
# Out:
# 7.5

# %%
#pembagian bulat
beli_roti=30
dibagikan=4
total= beli_roti//dibagikan
print(total)
# Out:
# 7

# %%
#sisa bagi
beli_roti=30
dibagikan=4
total= beli_roti%dibagikan
print(total)
# Out:
# 2

# %%
#sisa bagi lagi
beli_donat=25
dibagikan=6
total=beli_donat%dibagikan
print(total)
# Out:
# 1

# %%
#perpangkatan

# %% [markdown]
# #Operator logika dan Perbandingan

# %%
print (6>=6)
# Out:
# True

# %%
print (8==9)
# Out:
# False

# %%
print (8!=9)
# Out:
# True

# %%
print (8<10)
# Out:
# True

# %%
print (8>10)
# Out:
# False

# %%
print (5<=5)
# Out:
# True

# %%
print (8>7) and (6<5)
# Out:
# True

# %%
print (7<=1) or (2!=2)
# Out:
# False
# False

# %%
print (not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print (not(5<10 or 5<=10))
# Out:
# False
